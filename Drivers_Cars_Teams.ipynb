# %%
# Dependencies 
import pandas as pd
from datetime import datetime
from bs4 import BeautifulSoup
import glob as glob

# %%
# Set path of html file
drivers_html_path = 'drivers_html/drivers.htm'
# Read html file and store as html_content
with open(drivers_html_path, 'r') as drivers_file:
    drivers_html_content = drivers_file.read()

# %%
drivers_soup = BeautifulSoup(drivers_html_content, 'html.parser')

# %%
driver_details_html = 'driver-profile__driver-details'
drivers_html = drivers_soup.find_all('div', class_='driver-listing__driver-profile')
drivers_html
# Out:
# [<div class="driver-listing__driver-profile">
#  <a data-uw-original-href="https://www.indycar.com/Series/IndyCar-Series/Alex-Palou" data-uw-rm-brl="PR" href="https://www.indycar.com/Series/IndyCar-Series/Alex-Palou">
#  <img alt="Alex Palou" class="driver-profile__profile-image" data-uw-rm-alt="ALT" data-uw-rm-alt-original="Alex Palou" height="301" src="./drivers_files/AlexPalou.jpg" width="375"/>
#  </a>
#  <span class="driver-profile__driver-details">
#  <a data-uw-original-href="https://www.indycar.com/Series/IndyCar-Series/Alex-Palou" data-uw-rm-brl="PR" href="https://www.indycar.com/Series/IndyCar-Series/Alex-Palou">
#  <h2 class="secondary-heading">
#                                  Alex
#                                   Palou
#                              </h2>
#  </a>
#  <h3 class="tertiary-heading">
#                              Chip Ganassi Racing
#                          </h3>
#  <ul class="driver-profile__driver-sponsors">
#  <li class="driver-profile__sponsor">
# ...

# %%
for driver in drivers_html: 
    driver_name = driver.find(

# %%
driver_details_html = 'driver-profile__driver-details'
drivers_html1 = drivers_soup.find('div', class_='driver-listing__driver-profile')
drivers_html1
# Out:
# <div class="driver-listing__driver-profile">
# <a data-uw-original-href="https://www.indycar.com/Series/IndyCar-Series/Alex-Palou" data-uw-rm-brl="PR" href="https://www.indycar.com/Series/IndyCar-Series/Alex-Palou">
# <img alt="Alex Palou" class="driver-profile__profile-image" data-uw-rm-alt="ALT" data-uw-rm-alt-original="Alex Palou" height="301" src="./drivers_files/AlexPalou.jpg" width="375"/>
# </a>
# <span class="driver-profile__driver-details">
# <a data-uw-original-href="https://www.indycar.com/Series/IndyCar-Series/Alex-Palou" data-uw-rm-brl="PR" href="https://www.indycar.com/Series/IndyCar-Series/Alex-Palou">
# <h2 class="secondary-heading">
#                                 Alex
#                                  Palou
#                             </h2>
# </a>
# <h3 class="tertiary-heading">
#                             Chip Ganassi Racing
#                         </h3>
# <ul class="driver-profile__driver-sponsors">
# <li class="driver-profile__sponsor">
# ...

# %%
driver_name = drivers_html1.img['alt']
#car_team = [cell.get_text(strip=True) for cell in drivers_html1.find('h3')]
car_team = drivers_html1.find('h3').get_text()
car_details_html = drivers_html1.find_all("li")
car_number = car_details_html[0].img['alt']
#car_details.find_all('img')

# %%
print(driver_name)
#print(car_team)
#print(car_details_html)
print(car_number)
# Out:
# Alex Palou
# 10

# %%
<div class="driver-listing__driver-profile">
                    <a href="/Series/IndyCar-Series/Alex-Palou" data-uw-rm-brl="PR" data-uw-original-href="https://www.indycar.com/Series/IndyCar-Series/Alex-Palou">
                        <img src="https://digbza2f4g9qo.cloudfront.net/-/media/IndyCar/Drivers/IndyCar-Series/Driver-List/AlexPalou.jpg?h=301&amp;iar=0&amp;w=375" class="driver-profile__profile-image" alt="Alex Palou" width="375" height="301" data-uw-rm-alt-original="Alex Palou" data-uw-rm-alt="ALT">
                    </a>
                    <span class="driver-profile__driver-details">
                        <a href="/Series/IndyCar-Series/Alex-Palou" data-uw-rm-brl="PR" data-uw-original-href="https://www.indycar.com/Series/IndyCar-Series/Alex-Palou">
                            <h2 class="secondary-heading">
                                Alex
                                &nbsp;Palou
                            </h2>
                        </a>
                        <h3 class="tertiary-heading">
                            Chip Ganassi Racing
                        </h3>
                        <ul class="driver-profile__driver-sponsors">

                            <li class="driver-profile__sponsor">
                                <img src="https://digbza2f4g9qo.cloudfront.net/-/media/IndyCar/Cars/2024/IndyCar-Series/Endplates/10-Red-T.png?h=91&amp;iar=0&amp;w=130&amp;vs=1&amp;d=20240305T191357Z" class="driver-profile__profile-image" alt="10" width="130" height="91" data-uw-rm-alt-original="10" data-uw-rm-alt="ALT">
                            </li>
                            <li class="driver-profile__sponsor"><img src="https://digbza2f4g9qo.cloudfront.net/-/media/IndyCar/Logos/honda-logo-icon.png?h=44&amp;mh=44&amp;mw=63&amp;w=63&amp;hash=360253E4015904A935D15DF346530055&amp;vs=1&amp;d=20210323T203020Z" class="driver-profile__profile-image" alt="Sunoco Rookie" data-uw-rm-alt-original="Sunoco Rookie" data-uw-rm-alt="ALT"></li>
                            <li class="driver-profile__sponsor">
                                <img src="https://digbza2f4g9qo.cloudfront.net/-/media/IndyCar/Flags/Spain.png?h=150&amp;iar=0&amp;w=215&amp;vs=1&amp;d=20220310T214651Z" class="driver-profile__profile-image" alt="Spain" width="215" height="150" data-uw-rm-alt-original="Spain" data-uw-rm-alt="ALT">
                            </li>
                            
                            
                            <li class="driver-profile__sponsor"><img src="https://digbza2f4g9qo.cloudfront.net/~/media/IndyCar/Logos/P1-Logo.png?w=63&amp;h=44" class="driver-profile__profile-image" alt="Verizon P1 Award" data-uw-rm-alt-original="Verizon P1 Award" data-uw-rm-alt="ALT"></li>
                        </ul>
                    </span>
                    <span id="ctl01_ctl03_maincontent_0_rptStandingsDriver_tbStats_0" class="driver-profile__point-standings">
                        <table class="driver-profile__point-standings-table">
                            <tbody><tr>
                                <th>Rank</th>
                                <th>Wins</th>
                                <th>Poles</th>
                                <th>Points</th>
                            </tr>
                            <tr>
                                <td style="color: black;">
                                    1
                                </td>
                                <td style="color: black;">
                                    2
                                </td>
                                <td style="color: black;">
                                    3
                                </td>
                                <td style="color: black;">
                                    544
                                </td>
                            </tr>
                        </tbody></table>
                    </span>
                </div>
