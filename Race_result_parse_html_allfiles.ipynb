# %%
# Dependencies 
import pandas as pd
from datetime import datetime
from bs4 import BeautifulSoup
import glob as glob

# %%
# Set path of html file
races_html_path = 'Race_Results_HTML/stpetersburg.htm'
# Read html file and store as html_content
with open(races_html_path 'r') as races_file:
    html_content = races_file.read()

# %%
soup = BeautifulSoup(races_html_content, 'html.parser')

# %%
# Get the full-season table from HTML
season_html = soup.find(id = 'race-alltime')
season_data = []
# Loop through table html and parse to list
for row in season_html.find_all('tr'):
    row_data = [cell.get_text(strip=True) for cell in row.find_all(['th', 'td'])]
    season_data.append(row_data)
season_df = pd.DataFrame(season_data[1:], columns=season_data[0])
season_df["Date"] = pd.to_datetime(season_df["Date"])
season_df = season_df.drop([1, 2])
season_df = season_df.drop("Avg.Speed", axis=1).drop("Winner", axis=1).drop("Car/Engine", axis=1).drop("Start Position", axis=1)
season_df.reset_index(drop=True, inplace=True)
season_df.index += 1
season_df
# Out:
#          Date                                    Track     Track Type
# 1  2024-03-10                Streets of St. Petersburg  Street Course
# 2  2024-03-24                         The Thermal Club    Road Course
# 3  2024-04-21                    Streets of Long Beach  Street Course
# 4  2024-04-28                  Barber Motorsports Park    Road Course
# 5  2024-05-11  Indianapolis Motor Speedway Road Course    Road Course
# 6  2024-05-26              Indianapolis Motor Speedway           Oval
# 7  2024-06-02                       Streets of Detroit  Street Course
# 8  2024-06-09                             Road America    Road Course
# 9  2024-06-23          WeatherTech Raceway Laguna Seca    Road Course
# 10 2024-07-07               Mid-Ohio Sports Car Course    Road Course
# 11 2024-07-14                            Iowa Speedway           Oval
# 12 2024-07-14                            Iowa Speedway           Oval
# 13 2024-07-21                       Streets of Toronto  Street Course
# 14 2024-08-17            World Wide Technology Raceway           Oval
# 15 2024-08-25           Portland International Raceway    Road Course
# 16 2024-08-31                           Milwaukee Mile           Oval
# 17 2024-09-01                           Milwaukee Mile           Oval
# 18 2024-09-15                  Nashville Superspeedway           Oval

# %%
# Data Cleaning specific to 2024 season
# Correct the incorrect date of Iowa race 1
season_df.at[11, 'Date'] = '2024-07-13'
# Create row for shorthand race name
season_df.at[1, 'Race'] = 'St. Pete'
season_df.at[2, 'Race'] = 'Thermal'
season_df.at[3, 'Race'] = 'Long Beach'
season_df.at[4, 'Race'] = 'Barber'
season_df.at[5, 'Race'] = 'Indy Road Course'
season_df.at[6, 'Race'] = 'Indy 500'
season_df.at[7, 'Race'] = 'Detroit'
season_df.at[8, 'Race'] = 'Road America'
season_df.at[9, 'Race'] = 'Laguna Seca'
season_df.at[10, 'Race'] = 'Mid-Ohio'
season_df.at[11, 'Race'] = 'Iowa 1'
season_df.at[12, 'Race'] = 'Iowa 2'
season_df.at[13, 'Race'] = 'Toronto'
season_df.at[14, 'Race'] = 'Gateway'
season_df.at[15, 'Race'] = 'Portland'
season_df.at[16, 'Race'] = 'Milwaukee 1'
season_df.at[17, 'Race'] = 'Milwaukee 2'
season_df.at[18, 'Race'] = 'Nashville'
season_df
# Out:
#          Date                                    Track     Track Type  \
# 1  2024-03-10                Streets of St. Petersburg  Street Course
# 2  2024-03-24                         The Thermal Club    Road Course
# 3  2024-04-21                    Streets of Long Beach  Street Course
# 4  2024-04-28                  Barber Motorsports Park    Road Course
# 5  2024-05-11  Indianapolis Motor Speedway Road Course    Road Course
# 6  2024-05-26              Indianapolis Motor Speedway           Oval
# 7  2024-06-02                       Streets of Detroit  Street Course
# 8  2024-06-09                             Road America    Road Course
# 9  2024-06-23          WeatherTech Raceway Laguna Seca    Road Course
# 10 2024-07-07               Mid-Ohio Sports Car Course    Road Course
# 11 2024-07-13                            Iowa Speedway           Oval
# 12 2024-07-14                            Iowa Speedway           Oval
# 13 2024-07-21                       Streets of Toronto  Street Course
# 14 2024-08-17            World Wide Technology Raceway           Oval
# 15 2024-08-25           Portland International Raceway    Road Course
# 16 2024-08-31                           Milwaukee Mile           Oval
# 17 2024-09-01                           Milwaukee Mile           Oval
# 18 2024-09-15                  Nashville Superspeedway           Oval
#
#                 Race
# 1           St. Pete
# 2            Thermal
# 3         Long Beach
# 4             Barber
# 5   Indy Road Course
# 6           Indy 500
# 7            Detroit
# 8       Road America
# 9        Laguna Seca
# 10          Mid-Ohio
# 11            Iowa 1
# 12            Iowa 2
# 13           Toronto
# 14           Gateway
# 15          Portland
# 16       Milwaukee 1
# 17       Milwaukee 2
# 18         Nashville

# %%
all_files_path = 'Race_Results_HTML/*.htm'
race_results_files = []
race_results_files = glob.glob(all_files_path)

season_races_df = pd.DataFrame()

for race_result_file in race_results_files:
# Read html file and store as html_content
    with open(race_result_file, 'r') as file:
        html_content = file.read()
    # Parse race result table html
    soup = BeautifulSoup(html_content, 'html.parser')
    race_table_html = soup.find(id = 'race-season')
# Initialize a list to contain the race results 
    race_result_data = []
# Loop through table html and parse to list
    for row in race_table_html.find_all('tr'):
        row_data = [cell.get_text(strip=True) for cell in row.find_all(['th', 'td'])]
        race_result_data.append(row_data)

    race_result_df = pd.DataFrame(race_result_data[1:], columns=race_result_data[0])
    race_name = soup.find(id = 'season-event-name').text
    race_date = soup.find(id = 'season-session-date').text
    race_date = datetime.strptime(race_date, '%A, %B %d, %Y').date()
    race_winner = race_result_df.loc[race_result_df['Rank'] == '1', 'Driver'].iloc[0]
    race_pole = race_result_df.loc[race_result_df['Starts'] == '1', 'Driver'].iloc[0]
    race_avg_speed = race_result_df.loc[race_result_df['Rank'] == '1', 'Avg.Speed'].iloc[0]
    race_total_time = race_result_df.loc[race_result_df['Rank'] == '1', 'Total time'].iloc[0]
    race_laps = race_result_df.loc[race_result_df['Rank'] == '1', 'Laps'].iloc[0]
    race_info = {'Date': [race_date],
            'Race Name (Official)': [race_name],
            'Laps': [race_laps],
            'Winner': [race_winner],
            'Pole': [race_pole],
            'Avg. Speed': [race_avg_speed],
            'Total Time': [race_total_time],
            'Results': [race_result_df]}
    race_df = pd.DataFrame(race_info)
    race_df["Date"] = pd.to_datetime(race_df["Date"])
    race_df.reset_index(drop=True, inplace=True)
    race_df.index += 1
    season_races_df = pd.concat([season_races_df, race_df], axis=0)

season_races_df
# Out:
#         Date                    Race Name (Official) Laps            Winner  \
# 1 2024-06-02            Chevrolet Detroit Grand Prix  100       Scott Dixon
# 1 2024-04-21          Acura Grand Prix of Long Beach   85       Scott Dixon
# 15 2024-08-31                           Milwaukee Mile           Oval
# 16 2024-09-01                           Milwaukee Mile           Oval
# 17 2024-09-15                  Nashville Superspeedway           Oval
#
#                 Race                    Race Name (Official) Laps  \
# 1           St. Pete  Firestone Grand Prix of St. Petersburg  100
# 2         Long Beach          Acura Grand Prix of Long Beach   85
# 3             Barber   Children’s of Alabama Indy Grand Prix   90
# 4   Indy Road Course                       Sonsio Grand Prix   85
# 5           Indy 500   108th Running of the Indianapolis 500  200
# 6            Detroit            Chevrolet Detroit Grand Prix  100
# 7       Road America         XPEL Grand Prix at Road America   55
# 8        Laguna Seca        Firestone Grand Prix of Monterey   95
# 9           Mid-Ohio              Honda Indy 200 at Mid-Ohio   80
# 10            Iowa 1                     Hy-Vee One Step 250  250
# 11            Iowa 2                    Hy-Vee Homefront 250  250
# 12           Toronto      Ontario Honda Dealers Indy Toronto   85
# 13           Gateway          Bommarito Automotive Group 500  260
# 14          Portland      BITNILE.COM Grand Prix of Portland  110
# 15       Milwaukee 1      Hy-Vee Milwaukee Mile 250 - Race 1  250
# 16       Milwaukee 2      Hy-Vee Milwaukee Mile 250 - Race 2  250
# 17         Nashville       Big Machine Music City Grand Prix  206
#
#               Winner              Pole Avg. Speed     Total Time  \
# 1        Pato O'Ward   Josef Newgarden     96.752  01:51:37.5075
# 2        Scott Dixon  Felix Rosenqvist     98.350  01:42:03.1416
# 3   Scott McLaughlin  Scott McLaughlin    106.369  01:56:45.7773
# 4         Alex Palou        Alex Palou    117.956  01:45:27.2320
# 5    Josef Newgarden  Scott McLaughlin    167.763  02:58:49.4079
# 6        Scott Dixon      Colton Herta     78.251  02:06:07.9684
# 7         Will Power   Linus Lundqvist    126.154  01:45:00.0267
# 8         Alex Palou        Alex Palou    102.740  02:04:09.8545
# 9        Pato O'Ward        Alex Palou    116.071  01:33:22.6191
# 10        Will Power  Scott McLaughlin    154.768  01:26:38.7472
# 11  Scott McLaughlin      Colton Herta    128.098  01:44:41.1172
# 12      Colton Herta      Colton Herta     91.568  01:39:28.4293
# 13   Josef Newgarden  Scott McLaughlin    136.870  02:22:28.2772
# 14        Will Power  Santino Ferrucci    112.161  01:55:34.1948
# 15       Pato O'Ward  Scott McLaughlin    123.758  02:03:01.3451
# 16  Scott McLaughlin   Josef Newgarden    120.334  02:06:31.3981
# 17      Colton Herta     Kyle Kirkwood    159.207  01:43:15.2534
#
#                                               Results
# 1      Rank               Driver Car No. Starts La...
# 2      Rank               Driver Car No. Starts La...
# 3      Rank               Driver Car No. Starts La...
# 4      Rank               Driver Car No. Starts La...
# 5      Rank               Driver Car No. Starts La...
# 6      Rank               Driver Car No. Starts La...
# 7      Rank               Driver Car No. Starts La...
# 8      Rank               Driver Car No. Starts La...
# 9      Rank               Driver Car No. Starts La...
# 10     Rank               Driver Car No. Starts La...
# 11     Rank               Driver Car No. Starts La...
# 12     Rank               Driver Car No. Starts La...
# 13     Rank               Driver Car No. Starts La...
# 14     Rank               Driver Car No. Starts La...
# 15     Rank               Driver Car No. Starts La...
# 16     Rank               Driver Car No. Starts La...
# 17     Rank               Driver Car No. Starts La...
